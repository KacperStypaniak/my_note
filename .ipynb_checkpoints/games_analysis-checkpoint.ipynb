# %%
import pandas as pd
import matplotlib.pyplot as plt


games = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# games.head()
games.describe()
# games.info()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %%
# znajdź kolumny w których są braki w wartościach

games.isna().any()
games.isna().sum()
# games.isna().sum().plot(kind = 'bar')
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
#znajdź tylko pełne wiersze

only_full_rows = games.dropna().reset_index()
only_full_rows

# %%
# games by platform

games_by_platform = games.groupby(['Platform'])['Name'].count().to_frame(name='games_created').reset_index()
games_by_platform =games_by_platform.sort_values('games_created', ascending = False).reset_index(drop = True)
games_by_platform

# games_by_platform.plot(kind='bar',x = 'Platform', rot = 45)

# %%
# ilosc gier dla jednej platformy per rok

# games_pl_y[games_pl_y['Platform']=='NES'].plot(kind='line',x='Year_of_Release',y='games_released',title='Games released on NES by year')

# %%
# ilośc gier na platformy per rok + wizualizacja (dla NES,SNES,N64,WII,WIIU, PSX, PS2, PS3,PS4 Xbox, Xbox360,Xone)

platforms_filter = ('NES','SNES','N64','Wii','WiiU','PS','PS2','PS3','PS4','XB','X360','XOne') 

games_pl_y = games[games['Platform'].isin(platforms_filter)].groupby(['Platform','Year_of_Release'])['Name'].count().to_frame(name='games_released').reset_index()


# platforms = games_pl_y['Platform'].drop_duplicates().to_list()

for platform in platforms_filter:
    years_games = games_pl_y[games_pl_y['Platform']==platform]
    plt.plot(years_games['Year_of_Release'],years_games['games_released'],label= platform)

plt.title('Ilość gier wydanych per platforma')
plt.xlabel('Rok')
plt.ylabel('Ilość gier')
plt.legend()
    
plt.show()

# %%
# średnia i mediana ocena gry per platforma

# %%
# gry które wyszły na więcej niż jedną platformę
