# %%
import pandas as pd
import matplotlib.pyplot as plt


january_apts = pd.read_csv('apartments_pl_2024_01.csv')

january_apts.isna().any()

january_apts.head()
# Out:
#                                  id      city               type  \
# 0  a01d82c9529f98a54d64b9e061c9a73b  szczecin  apartmentBuilding
# 1  8373aa373dbc3fe7ca3b7434166b8766  szczecin           tenement
# 2  7d0c31d5409caab173571cce3dcdf702  szczecin       blockOfFlats
# 3  3eaa36a59b9354206703b5f6b2f2ff1d  szczecin       blockOfFlats
# 4  027b30cebbc49faf3094421b741ddd56  szczecin       blockOfFlats
#
#    squareMeters  rooms  floor  floorCount  buildYear   latitude  longitude  \
# 0        105.00    4.0    3.0         4.0     2016.0  53.431503  14.485820
# 1         73.02    3.0    2.0         3.0        NaN  53.452222  14.553333
# 2         68.61    3.0    4.0         4.0     1997.0  53.456213  14.583222
# 3         42.00    2.0    1.0         3.0        NaN  53.468056  14.538333
# 4         45.50    2.0    4.0         4.0     1960.0  53.438165  14.563200
#
#    ...  pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
pvt = january_apts.pivot_table(values = 'squareMeters',index = 'type', aggfunc = ['mean','median','count'])

pvt.columns = ['średnia','mediana','ilość']
pvt.reset_index(inplace = True)
pvt
# Out:
#                 type    średnia  mediana  ilość
# 0  apartmentBuilding  62.626704    59.40   2882
# 1       blockOfFlats  56.082299    53.30   6704
# 2           tenement  67.099104    62.34   2479

# %%
# wybierz kolumny type i squareMeters i wiersze od 1 do 7 (bez 0)

# print(january_apts[['type','squareMeters']].iloc[1:7])

# january_apts.loc[1:7,'type':'squareMeters']

january_no_index = january_apts.reset_index(drop = True)
january_no_index = january_no_index.set_index('id')

january_no_index.loc[:'027b30cebbc49faf3094421b741ddd56','type':'squareMeters']


# january_apts.iloc[1:7,2:4]



## select top 100 ;)

january_apts.loc[:99,:]
# Out:
#                                   id      city               type  \
# 0   a01d82c9529f98a54d64b9e061c9a73b  szczecin  apartmentBuilding
# 1   8373aa373dbc3fe7ca3b7434166b8766  szczecin           tenement
# 2   7d0c31d5409caab173571cce3dcdf702  szczecin       blockOfFlats
# 3   3eaa36a59b9354206703b5f6b2f2ff1d  szczecin       blockOfFlats
# 4   027b30cebbc49faf3094421b741ddd56  szczecin       blockOfFlats
# ..                               ...       ...                ...
# 95  80678a17024d65391ca23f83ee014295  szczecin       blockOfFlats
# 96  63a7280a8e57dc259293e5bdb18e471c  szczecin           tenement
# 97  d879ace59a3effe66ae8dff21f4baef2  szczecin  apartmentBuilding
# 98  a9f2e8fcfa89b3d57986a00d930161e3  szczecin       blockOfFlats
# 99  d3cef3cae0a119d6d4e1edd32b70d8fb  szczecin       blockOfFlats
#
#     squareMeters  rooms  floor  floorCount  buildYear   latitude  longitude  \
# 0         105.00    4.0    3.0         4.0     2016.0  53.431503  14.485820
# ...

# %%
january_apts


january_apts.pivot(index = 'id', columns = ['city'], values = 'squareMeters')



# df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
#                            'two'],
#                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
#                    'baz': [1, 2, 3, 4, 5, 6],
#                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
# print(df)



# df.pivot(index='foo', columns='bar', values='baz')
# Out:
# city                              bialystok  bydgoszcz  czestochowa  gdansk  \
# id
# 0008f66ddcf09af1284cc3a271e98144        NaN        NaN          NaN     NaN
# 000a7386d96f274f02e19cbe17c50d6a        NaN        NaN          NaN   72.64
# 000d8e5104e4688de4da4ce3d9b3db21        NaN        NaN          NaN     NaN
# 000f9c10ab7bab5e21b0409df27145a5        NaN        NaN          NaN   61.80
# 00124137f9c63a57c526f878573c5898        NaN        NaN          NaN     NaN
# ...                                     ...        ...          ...     ...
# ffe9592fbd7a164fec43ceaa4913fadf        NaN        NaN          NaN     NaN
# fff075d963f1865140c0434b9777f6b4        NaN        NaN          NaN     NaN
# fff537c5d0ae74907edf8be30ff7d75d        NaN        NaN          NaN     NaN
# fff953e1d3e2dce22e1f32bcf37d4249        NaN        NaN          NaN     NaN
# ffff369f1fb57bff8d9180282051be1a        NaN        NaN         67.0     NaN
#
# ...

# %%
ax = january_apts.pivot_table(index = 'type', columns = 'city', values = 'squareMeters', aggfunc= ('mean'))




# print(ax)

ax = ax.plot(kind = 'line',xlabel = 'type')
ax.legend('')
